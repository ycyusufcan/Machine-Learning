# %%
from sklearn.datasets import make_blobs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
X,y=make_blobs(n_samples=1000, n_features=2, centers=2)

# %%
plt.scatter(X.T[0], X.T[1], c=y)

# %%
from keras.models import Sequential
# Out:
# Using TensorFlow backend.

# %%
from keras.layers import Dense

# %%
model=Sequential()

# %%
model.add(Dense(4,input_shape=(2,),activation="tanh"))

# %%
model.add(Dense(2, activation='tanh'))
model.add(Dense(2, activation='tanh'))
model.add(Dense(2, activation='tanh'))

# %%
model.add(Dense(1,activation="sigmoid"))

# %%
from keras.optimizers import SGD
LEARNING_RATE = 0.01
sgd_instance = SGD(lr=LEARNING_RATE)
model.compile(optimizer=sgd_instance,loss="binary_crossentropy")

# %%
from sklearn.model_selection import train_test_split
EPOCHS=100
BATCH_SIZE=32
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
model.fit(X_train,y_train,epochs=EPOCHS, batch_size=BATCH_SIZE)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.5189
# Epoch 2/100
# 800/800 [==============================] - 0s 100us/step - loss: 0.3897
# Epoch 3/100
# 800/800 [==============================] - 0s 100us/step - loss: 0.3469
# Epoch 4/100
# 800/800 [==============================] - 0s 50us/step - loss: 0.3184
# Epoch 5/100
# 800/800 [==============================] - 0s 50us/step - loss: 0.2959
# Epoch 6/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.2769
# Epoch 7/100
# 800/800 [==============================] - 0s 50us/step - loss: 0.2605
# Epoch 8/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.2459
# Epoch 9/100
# 800/800 [==============================] - 0s 50us/step - loss: 0.2328
# Epoch 10/100
# 800/800 [==============================] - 0s 50us/step - loss: 0.2210
# Epoch 11/100
# 800/800 [==============================] - 0s 40us/step - loss: 0.2101
# Epoch 12/100
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred_train = model.predict(X_train)

# %%
y_pred_train[:5]
# Out:
# array([[0.02523449],
#        [0.0260812 ],
#        [0.02502701],
#        [0.9741465 ],
#        [0.9741299 ]], dtype=float32)

# %%
accuracy_score(y_train, (y_pred_train > 0.5))
# Out:
# 1.0

# %%
y_pred_test = model.predict(X_test)
accuracy_score(y_test, (y_pred_test > 0.5))
# Out:
# 1.0

# %%
np.random.seed(0)
X = np.random.randn(1000, 9)
X[:, 0] = 1
beta = [-2, 4, 9, 2, 9, 5, 1, -4, 5]
y = X @ np.array(beta).reshape(-1, 1) + (10 + 2 * np.random.randn(1000).reshape(-1, 1))

# %%
X.shape
# Out:
# (1000, 9)

# %%
y.shape
# Out:
# (1000, 1)

# %%
model=Sequential()
model.add(Dense(4,input_shape=(9,), activation="tanh"))
model.add(Dense(8,activation="tanh"))
model.add(Dense(8,activation="tanh"))
model.add(Dense(8,activation="tanh"))
model.add(Dense(1))

# %%
model.compile(optimizer=sgd_instance,loss="mean_squared_error")

# %%
from sklearn.metrics import r2_score

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
history = model.fit(X_train,y_train, epochs=100,verbose=0)
history.history['loss'][-1]
plt.plot(history.history['loss'])
y_pred_test = model.predict(X_test)
y_pred_train = model.predict(X_train)

r2_score(y_pred_train,y_train)
# Out:
# 0.9750822810923356

# %%
r2_score(y_pred_test, y_test)
# Out:
# 0.9761579736396626

# %%
from sklearn.datasets import make_blobs
CENTERS = 4
X, y = make_blobs(n_samples=1000, n_features=2, centers=CENTERS)

plt.scatter(X.T[0], X.T[1], c=y,cmap="jet")
