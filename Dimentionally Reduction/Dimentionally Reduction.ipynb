# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
population=pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population")

# %%
population[0].head()
# Out:
#   Rank Country(or dependent territory)  Population               Date  \
# 0    1                   China[Note 2]  1399940000  November 10, 2019
# 1    2                           India  1354640000  November 10, 2019
# 2    3           United States[Note 3]   330218000  November 10, 2019
# 3    4                       Indonesia   266911900       July 1, 2019
# 4    5                          Brazil   210699000  November 10, 2019
#
#   % of worldpopulation                      Source
# 0                18.1%   Official population clock
# 1                17.5%   Official population clock
# 2                4.26%   Official population clock
# 3                  NaN  Official annual projection
# 4                2.72%   Official population clock

# %%
gdp=pd.read_csv("countries of the world.csv")

# %%
gdp.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
life=pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_by_past_life_expectancy")

# %%
life=life[2]

# %%
life.head()
# Out:
#   Country/dependent territory  1950-1955  1955-1960  1960-1965  1965-1970  \
# 0                 Afghanistan      28.61      31.12      33.41      35.58
# 1                     Albania      55.26      59.31      64.85      66.24
# 2                     Algeria      42.89      45.00      47.29      49.47
# 3                      Angola      31.39      32.54      34.09      36.04
# 4         Antigua and Barbuda      58.51      61.03      63.18      65.05
#
#    1970-1975  1975-1980  1980-1985  1985-1990  1990-1995  1995-2000  \
# 0      37.83      40.39      43.56      47.70      51.74      54.17
# 1      67.69      69.70      70.61      71.98      71.73      72.95
# 2      51.48      54.93      61.57      65.85      67.20      69.14
# 3      38.05      40.00      40.89      41.48      42.22      44.73
# 4      66.71      68.18      69.54      70.75      71.88      73.00
#
#    2000-2005  2005-2010  2010-2015
# 0      56.89      60.03      62.25
# 1      74.83      75.65      77.66
# ...

# %%
military=pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_by_number_of_military_and_paramilitary_personnel")

# %%
military=military[0]

# %%
gdp.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
life.head()
# Out:
#   Country/dependent territory  1950-1955  1955-1960  1960-1965  1965-1970  \
# 0                 Afghanistan      28.61      31.12      33.41      35.58
# 1                     Albania      55.26      59.31      64.85      66.24
# 2                     Algeria      42.89      45.00      47.29      49.47
# 3                      Angola      31.39      32.54      34.09      36.04
# 4         Antigua and Barbuda      58.51      61.03      63.18      65.05
#
#    1970-1975  1975-1980  1980-1985  1985-1990  1990-1995  1995-2000  \
# 0      37.83      40.39      43.56      47.70      51.74      54.17
# 1      67.69      69.70      70.61      71.98      71.73      72.95
# 2      51.48      54.93      61.57      65.85      67.20      69.14
# 3      38.05      40.00      40.89      41.48      42.22      44.73
# 4      66.71      68.18      69.54      70.75      71.88      73.00
#
#    2000-2005  2005-2010  2010-2015
# 0      56.89      60.03      62.25
# 1      74.83      75.65      77.66
# ...

# %%
military.head()
# Out:
#    Flag                 Country  Active military  Reserve military  \
# 0   NaN          Afghanistan[1]           174300                 0
# 1   NaN              Albania[2]             8000                 0
# 2   NaN              Algeria[3]           130000            150000
# 3   NaN               Angola[4]           107000                 0
# 4   NaN  Antigua and Barbuda[5]              180                80
#
#    Paramilitary   Total  Per 1000 capita(total)  Per 1000 capita(active)
# 0        148700  323000                     9.5                      5.1
# 1           500    8500                     2.8                      2.6
# 2        187200  467200                    11.4                      3.2
# 3         10000  117000                     4.0                      3.7
# 4             0     260                     2.7                      1.9

# %%
military=military.drop('Flag',axis=1)

# %%
military.head()
# Out:
#                   Country  Active military  Reserve military  Paramilitary  \
# 0          Afghanistan[1]           174300                 0        148700
# 1              Albania[2]             8000                 0           500
# 2              Algeria[3]           130000            150000        187200
# 3               Angola[4]           107000                 0         10000
# 4  Antigua and Barbuda[5]              180                80             0
#
#     Total  Per 1000 capita(total)  Per 1000 capita(active)
# 0  323000                     9.5                      5.1
# 1    8500                     2.8                      2.6
# 2  467200                    11.4                      3.2
# 3  117000                     4.0                      3.7
# 4     260                     2.7                      1.9

# %%
import re

# %%
deneme='Afgha nistan[1]'
patern=r"[^A-Za-z\s]"
re.sub(patern,'',deneme)
# Out:
# 'Afgha nistan'

# %%
military['Country']=military['Country'].apply(lambda x:re.sub(patern,'',x))

# %%
military.head()
# Out:
#                Country  Active military  Reserve military  Paramilitary  \
# 0          Afghanistan           174300                 0        148700
# 1              Albania             8000                 0           500
# 2              Algeria           130000            150000        187200
# 3               Angola           107000                 0         10000
# 4  Antigua and Barbuda              180                80             0
#
#     Total  Per 1000 capita(total)  Per 1000 capita(active)
# 0  323000                     9.5                      5.1
# 1    8500                     2.8                      2.6
# 2  467200                    11.4                      3.2
# 3  117000                     4.0                      3.7
# 4     260                     2.7                      1.9

# %%
life.head()
# Out:
#   Country/dependent territory  1950-1955  1955-1960  1960-1965  1965-1970  \
# 0                 Afghanistan      28.61      31.12      33.41      35.58
# 1                     Albania      55.26      59.31      64.85      66.24
# 2                     Algeria      42.89      45.00      47.29      49.47
# 3                      Angola      31.39      32.54      34.09      36.04
# 4         Antigua and Barbuda      58.51      61.03      63.18      65.05
#
#    1970-1975  1975-1980  1980-1985  1985-1990  1990-1995  1995-2000  \
# 0      37.83      40.39      43.56      47.70      51.74      54.17
# 1      67.69      69.70      70.61      71.98      71.73      72.95
# 2      51.48      54.93      61.57      65.85      67.20      69.14
# 3      38.05      40.00      40.89      41.48      42.22      44.73
# 4      66.71      68.18      69.54      70.75      71.88      73.00
#
#    2000-2005  2005-2010  2010-2015
# 0      56.89      60.03      62.25
# 1      74.83      75.65      77.66
# ...

# %%
life=life.rename({"Country/dependent territory":"Country"},axis=1)

# %%
gdp.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
life['Country']=life['Country'].apply(lambda x:re.sub(patern,'',x))

# %%
gdp['Country']=gdp['Country'].str.strip()

# %%
df=gdp.merge(life).merge(military)

# %%
from sklearn.preprocessing import StandardScaler as ss
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer

# %%
df.isna().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          0
# Infant mortality (per 1000 births)     0
# GDP ($ per capita)                     0
# Literacy (%)                           1
# Phones (per 1000)                      1
# Arable (%)                             0
# Crops (%)                              0
# Other (%)                              0
# Climate                               13
# Birthrate                              1
# Deathrate                              1
# Agriculture                            0
# Industry                               0
# Service                                0
# 1950-1955                              0
# 1955-1960                              0
# 1960-1965                              0
# ...

# %%
df.head()
# Out:
#        Country                               Region  Population  \
# 0  Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1      Albania  EASTERN EUROPE                          3581655
# 2      Algeria  NORTHERN AFRICA                        32930091
# 3       Angola  SUB-SAHARAN AFRICA                     12127071
# 4    Argentina              LATIN AMER. & CARIB        39921833
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3         1246700                        9,7                         0,13
# 4         2766890                       14,4                         0,18
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
df.dtypes
# Out:
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)             object
# Coastline (coast/area ratio)           object
# Net migration                          object
# Infant mortality (per 1000 births)     object
# GDP ($ per capita)                    float64
# Literacy (%)                           object
# Phones (per 1000)                      object
# Arable (%)                             object
# Crops (%)                              object
# Other (%)                              object
# Climate                                object
# Birthrate                              object
# Deathrate                              object
# Agriculture                            object
# Industry                               object
# Service                                object
# ...

# %%
df.iloc[:,2:]=df.iloc[:,2:].apply(lambda x:pd.to_numeric(x.str.replace(',','.')) if x.dtype=='object'else x)

# %%
df.dtypes
# Out:
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)            float64
# Coastline (coast/area ratio)          float64
# Net migration                         float64
# Infant mortality (per 1000 births)    float64
# GDP ($ per capita)                    float64
# Literacy (%)                          float64
# Phones (per 1000)                     float64
# Arable (%)                            float64
# Crops (%)                             float64
# Other (%)                             float64
# Climate                               float64
# Birthrate                             float64
# Deathrate                             float64
# Agriculture                           float64
# Industry                              float64
# Service                               float64
# ...

# %%
x=df.iloc[:,2:]

# %%
scaler=ss()

# %%
imputer=SimpleImputer()

# %%
x=imputer.fit_transform(x)

# %%
X_scaled=scaler.fit_transform(x)

# %%
model=PCA(n_components=2)

# %%
X_scaled.mean()
# Out:
# -4.398086296757377e-17

# %%
X_pca=model.fit_transform(X_scaled)

# %%
plt.figure(figsize=(20,12))
plt.scatter(X_pca[:,0],X_pca[:,1])
for i in range(df.shape[0]):
    plt.text(X_pca[i,0],X_pca[i,1],df['Country'][i])

# %%
model2=PCA()

# %%
X_pca2=model2.fit_transform(X_scaled)

# %%
model2.explained_variance_ratio_
# Out:
# array([4.66316814e-01, 1.15879454e-01, 7.40433741e-02, 5.25806628e-02,
#        4.48412200e-02, 3.63247808e-02, 3.44446965e-02, 2.70417855e-02,
#        2.27979351e-02, 1.87936199e-02, 1.82807956e-02, 1.62407106e-02,
#        1.34943875e-02, 1.23480680e-02, 1.06715284e-02, 7.59294804e-03,
#        5.93770006e-03, 4.88930387e-03, 4.49908559e-03, 2.96907621e-03,
#        2.12881564e-03, 1.91689908e-03, 1.76101233e-03, 1.46257959e-03,
#        1.02177756e-03, 6.12552348e-04, 4.51024629e-04, 3.32255907e-04,
#        1.19308867e-04, 7.12144400e-05, 4.58971551e-05, 3.44984344e-05,
#        2.43299956e-05, 1.87282817e-05, 1.11547868e-05, 4.21120843e-09,
#        2.45129501e-33])

# %%
import numpy as np

# %%
np.cumsum(model2.explained_variance_ratio_)
# Out:
# array([0.46631681, 0.58219627, 0.65623964, 0.70882031, 0.75366153,
#        0.78998631, 0.824431  , 0.85147279, 0.87427072, 0.89306434,
#        0.91134514, 0.92758585, 0.94108024, 0.9534283 , 0.96409983,
#        0.97169278, 0.97763048, 0.98251978, 0.98701887, 0.98998795,
#        0.99211676, 0.99403366, 0.99579467, 0.99725725, 0.99827903,
#        0.99889158, 0.99934261, 0.99967486, 0.99979417, 0.99986539,
#        0.99991128, 0.99994578, 0.99997011, 0.99998884, 1.        ,
#        1.        , 1.        ])

# %%
from sklearn.manifold import TSNE

# %%
modelTSNE= TSNE()

# %%
X_tsne=modelTSNE.fit_transform(X_scaled)

# %%
plt.figure(figsize=(20,12))
plt.scatter(X_tsne[:,0],X_tsne[:,1])
for i in range(df.shape[0]):
    plt.text(X_tsne[i,0],X_tsne[i,1],df['Country'][i])

# %%
sigma=np.cov(X_scaled.T)

# %%
u,s,v=np.linalg.svd(sigma)

# %%
u_red=u[:,:2]

# %%
u_red.shape
# Out:
# (37, 2)

# %%
X_manuel=X_scaled@u_red

# %%
X_manuel[0]
# Out:
# array([-7.27190974, -0.51494325])

# %%
X_pca[0]
# Out:
# array([7.27190974, 0.51494325])

# %%
X_manuel_T=u_red.T@X_scaled.T

# %%
X_manuel_T[:,0]
# Out:
# array([-7.27190974, -0.51494325])
